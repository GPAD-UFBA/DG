# %%
# Pre-processing
from gpad_data_generation import *
# To listen
import sounddevice as sd

# %%
# The file you want to import must be in /Music/
filename = "Music/120bpm_jazz.mp3"

# Music Loader
musica_inteira = music_loading(filename, sample_rate=44100)

# Only selecting from 12.889s to 23.78s
# PS: time = samples/sample_rate
musica = musica_inteira[2**19:2**19+2**19] 

# ODFs and PeDFs generation from wavelet coefficients
nivel_wavelet = 5
ODF_SET, PeDF_FULL_SET, PeDF_PARTIAL_SET, coeffs = preprocess(musica, nivel_wavelet)

# %%
# The same as the previous cell, but resumed!
# All the tunable parameters are inside music_processor

filename = "Music/120bpm_jazz.wav"
ODF_SET, PeDF_FULL_SET, PeDF_PARTIAL_SET, coeffs = music_processor(filename)

# %%
# Listening

sd.play(coeffs[5], 44100/2)

# %%
# Visualization

index = 5 # #cAN, cDN, cD(N-1), cD(N-2), .... based in level = N

plot_ODF(ODF_SET[index],index=index,size=len(coeffs))
plot_PeDF(PeDF_FULL_SET[index], form="full",index=index,size=len(coeffs))
plot_PeDF(PeDF_PARTIAL_SET[index], form="partial",index=index,size=len(coeffs))

print(f"1 ODF's sample is equivalent to {np.round((2**19/44100)/len(ODF_SET[index])*1000,2)}ms")
print(f"This ODF has {len(ODF_SET[index])} samples")
# Out:
# 1 ODF's sample is equivalent to 19.98ms
# This ODF has 595 samples

# %%
# How to know what each function does

help(convert_mp3_to_wav)
help(music_loading)
help(ODF_SuperFlux)
help(PeDF)
help(preprocess)
help(music_processor)
help(plot_ODF)
help(plot_PeDF)
# Out:
# Help on function convert_mp3_to_wav in module gpad_data_generation:
#
# convert_mp3_to_wav(filename)
#     converts a mp3 file to a wav file
#
#     Arguments:
#     filename -- string with the name of the mp3 file
#                 e.g.: filename = "/Music/saudade.mp3"
#
#     Returns:
#     /~/filename.wav
#
# Help on function music_loading in module gpad_data_generation:
#
# music_loading(filename, sample_rate=44100)
#     loads one music to the memory as a normalized numpy array
#
#     Arguments:
#     filename    -- string with the name of the mp3 file
#                    e.g.: filename = "/Music/saudade.mp3"
#     sample_rate -- [OPTIONAL] sample rate of the music in Hertz
#
#     Returns:
#     musica      -- a numpy array of dimensions (n,1) with n the number of samples of the music
#
# Help on function ODF_SuperFlux in module gpad_data_generation:
#
# ODF_SuperFlux(signal, sample_rate, frame_size, hop)
#     computes the Onset Detection Function of a signal
#
# ...
